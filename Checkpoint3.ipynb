# %%
import pandas as pd;

#lecture du fichier
#with open("titanic-passengers.csv",'r') as file:
#    new_file=file.read()
    

#remplacer les ; en  et les , en espace vide
#new_file=new_file.replace(","," ")
#new_file=new_file.replace(";",",")


#ecriture dans le fichier
#with open("titanic-passengers.csv",'w') as file:
#    file.write(new_file)

# %%
#importation de la bibliothéque pandas
import pandas as pd;

#création de dataframe from csv
df=pd.read_csv("titanic-passengers.csv",encoding='ISO-8859-1')
#affichage des 5 premieres données avec leur entete
df.head()
# Out:
#    PassengerId Survived  Pclass                                         Name  \
# 0          343       No       2                   Collander  Mr. Erik Gustaf
# 1           76       No       3                      Moen  Mr. Sigurd Hansen
# 2          641       No       3                       Jensen  Mr. Hans Peder
# 3          568       No       3  Palsson  Mrs. Nils (Alma Cornelia Berglund)
# 4          672       No       1                       Davidson  Mr. Thornton
#
#       Sex   Age  SibSp  Parch      Ticket     Fare  Cabin Embarked
# 0    male  28.0      0      0      248740  13.0000    NaN        S
# 1    male  25.0      0      0      348123   7.6500  F G73        S
# 2    male  20.0      0      0      350050   7.8542    NaN        S
# 3  female  29.0      0      4      349909  21.0750    NaN        S
# 4    male  31.0      1      0  F.C. 12750  52.0000    B71        S

# %%
#remplacer les mots en chiffres
df=df.replace("No","0")
df=df.replace("Yes","1")
df.to_csv("titanic-update.csv",encoding='ISO-8859-1')
df
# Out:
#      PassengerId Survived  Pclass  \
# 0            343        0       2
# 1             76        0       3
# 2            641        0       3
# 3            568        0       3
# 4            672        0       1
# ..           ...      ...     ...
# 886           10        1       2
# 887           61        0       3
# 888          535        0       3
# 889          102        0       3
# 890          428        1       2
#
#                                                   Name     Sex   Age  SibSp  \
# 0                           Collander  Mr. Erik Gustaf    male  28.0      0
# 1                              Moen  Mr. Sigurd Hansen    male  25.0      0
# 2                               Jensen  Mr. Hans Peder    male  20.0      0
# 3          Palsson  Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                               Davidson  Mr. Thornton    male  31.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
##supression des lignes null
#df.dropna(axis=0)

#visualiation des 5 premiere ligne
print(df['Cabin'].head())

#somme des nulle dans Cabin
df['Cabin'].isnull().sum()

#somme des nulle dans pour chaque colonne du dataframe
df.isnull().sum()
#somme des nulle dans tout le dataframe
df['Cabin'].isnull().sum().sum()

#remplacement de la valeur manquante par la moyenne de tte la colonne age
df['Age'].fillna(df['Age'].mean(),inplace=True)

x=df['Cabin']
numb_elements=len(x)
print(numb_elements)
#nombre d'éléments par catégorie
print(x.value_counts())
#remplacer et afficher les valeurs
x.fillna('G6',inplace=True)
df
# Out:
# 0      NaN
# 1    F G73
# 2      NaN
# 3      NaN
# 4      B71
# Name: Cabin, dtype: object
# 891
# G6             4
# B96 B98        4
# C23 C25 C27    4
# F33            3
# D              3
#               ..
# C91            1
# D45            1
# F G63          1
# A34            1
# E63            1
# Name: Cabin, Length: 147, dtype: int64
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex        Age  \
# 0                           Collander  Mr. Erik Gustaf    male  28.000000
# ...

# %%
df.info()
#convertir le type age( float) en int
df['Age']=df['Age'].astype('int64')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    object
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        891 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 83.7+ KB

# %%
df
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex  Age  SibSp  \
# 0                           Collander  Mr. Erik Gustaf    male   28      0
# 1                              Moen  Mr. Sigurd Hansen    male   25      0
# 2                               Jensen  Mr. Hans Peder    male   20      0
# 3          Palsson  Mrs. Nils (Alma Cornelia Berglund)  female   29      0
# 4                               Davidson  Mr. Thornton    male   31      1
# ..                                                 ...     ...  ...    ...
# ...

# %%
#df.info()
#df_sex= df['Sex']
# etiquetage
# from sklearn.preprocessing import LabelEncoder
# encoder=LabelEncoder()
# df_sex=encoder.fit_transform(df_sex)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    object
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    int64
#  5   Age          891 non-null    int64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        891 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(1), int64(6), object(5)
# memory usage: 83.7+ KB

# %%
#etiquetage du sexe
#num_sex={"Sex":{"male":1,"female":2}}
#df.replace(num_sex,inplace=True)
df

#etiquetage du cabin

df["Cabin"].value_counts()
num_cabin={"Cabin":{"G6":3,"C23":4, "C25":5, "C27":6,"D":7, "C22":8, "C26":9,          
"D45":10,           
"F G63" :11,        
"A34":12,        
"C85":13,          
"E63":14,
"F G73" :15,
"B71":16}}
df.replace(num_cabin,inplace=True)
df
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex  Age  SibSp  \
# 0                           Collander  Mr. Erik Gustaf    male   28      0
# 1                              Moen  Mr. Sigurd Hansen    male   25      0
# 2                               Jensen  Mr. Hans Peder    male   20      0
# 3          Palsson  Mrs. Nils (Alma Cornelia Berglund)  female   29      0
# 4                               Davidson  Mr. Thornton    male   31      1
# ..                                                 ...     ...  ...    ...
# ...

# %%
#diagramme en bar en fonction de l'age
df
import matplotlib.pyplot as plt
plt.title("Diagramme en barre des ages")
plt.xlabel("Age")

df["Age"].plot.hist()

#df["Age"].plot.bar()

#commentaire
# on constate qu'on a plus de victimes agé de 25-30ans
# Out:
# <AxesSubplot:title={'center':'Diagramme en barre des ages'}, xlabel='Age', ylabel='Frequency'>

# %%
df.info()
#convertir le type age( float) en int
df['Age']=df['Age'].astype('int64')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    object
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    int64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        891 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(1), int64(5), object(6)
# memory usage: 83.7+ KB

# %%
df
# Out:
#      PassengerId Survived  Pclass  \
# 0            343        0       2
# 1             76        0       3
# 2            641        0       3
# 3            568        0       3
# 4            672        0       1
# ..           ...      ...     ...
# 886           10        1       2
# 887           61        0       3
# 888          535        0       3
# 889          102        0       3
# 890          428        1       2
#
#                                                   Name     Sex  Age  SibSp  \
# 0                           Collander  Mr. Erik Gustaf    male   28      0
# 1                              Moen  Mr. Sigurd Hansen    male   25      0
# 2                               Jensen  Mr. Hans Peder    male   20      0
# 3          Palsson  Mrs. Nils (Alma Cornelia Berglund)  female   29      0
# 4                               Davidson  Mr. Thornton    male   31      1
# ..                                                 ...     ...  ...    ...
# ...

# %%
df
#import bibliotheque
import seaborn as sns
#corrélation en  bar avec catplot. 
sns.catplot(x="Sex", y="Age",hue="Survived",kind="bar", data= df)
#les déductions concernant l'importance de l'âge et du sexe dans la survie des individus.
# nous constatons  qu'on a plus d'hommes agés de plus de  26ans qui n'ont pas survécu
#mais, on a plus de femmes survécu agé de moind de 29ans

# %%
# correlation en bar 2em methode avec facetgrid
grid = sns.FacetGrid(df, row="Sex", col="Survived", height=2.2, aspect=1.6)
grid.map(sns.barplot, "Age", alpha=.5, ci=None)
grid.add_legend()

#les déductions concernant l'importance de l'âge et du sexe dans la survie des individus.
# nous constatons  qu'on a plus d'hommes agés de plus de  26ans qui n'ont pas survécu
#mais, on a plus de femmes survécu agé de moins de 29ans
# Out:
# C:\Users\Codou\anaconda3\lib\site-packages\seaborn\axisgrid.py:670: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
def plot_correlation_map(df):

    corr = df.corr()
    s , ax = plt.subplots( figsize =( 12 , 10 ) )
    cmap = sns.diverging_palette( 220 , 10 , as_cmap = True )
    s = sns.heatmap(
        corr, 
        cmap = cmap,
        square=True, 
        cbar_kws={ 'shrink' : .9 }, 
        ax=ax, 
        annot = True, 
        annot_kws = { 'fontsize' : 12 }
        )
plot_correlation_map(df)

# %%
#impact entr la relation  pclass et survived
df[["Pclass", "Survived"]].groupby(["Survived"], as_index=True).mean()
#il y a moins de survivant

df
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex  Age  SibSp  \
# 0                           Collander  Mr. Erik Gustaf    male   28      0
# 1                              Moen  Mr. Sigurd Hansen    male   25      0
# 2                               Jensen  Mr. Hans Peder    male   20      0
# 3          Palsson  Mrs. Nils (Alma Cornelia Berglund)  female   29      0
# 4                               Davidson  Mr. Thornton    male   31      1
# ..                                                 ...     ...  ...    ...
# ...

# %%
#creation dataframe
df
new_data=pd.DataFrame(df)

#insertion de la nouvelle colonne avec affectation des valeurs du name supprimé précédemment
new_data["Titre"]=new_data["Name"]

#suppression la colonne noms
new_data=new_data.drop(["Name"],axis=1)

new_data
# Out:
#      PassengerId Survived  Pclass     Sex  Age  SibSp  Parch      Ticket  \
# 0            343       No       2    male   28      0      0      248740
# 1             76       No       3    male   25      0      0      348123
# 2            641       No       3    male   20      0      0      350050
# 3            568       No       3  female   29      0      4      349909
# 4            672       No       1    male   31      1      0  F.C. 12750
# ..           ...      ...     ...     ...  ...    ...    ...         ...
# 886           10      Yes       2  female   14      1      0      237736
# 887           61       No       3    male   22      0      0        2669
# 888          535       No       3  female   30      0      0      315084
# 889          102       No       3    male   29      0      0      349215
# 890          428      Yes       2  female   19      0      0      250655
#
#         Fare Cabin Embarked                                              Titre
# ...

# %%
#Visualisez la corrélation entre le titre et d'autres caractéristiques (par exemple, le sexe, le tarif, l'âge...)
gridn = sns.FacetGrid(new_data, row="Age", col="Sex",  height=2.2, aspect=1.6)
gridn.map(sns.barplot, "Age", alpha=.5, ci=None)
gridn.add_legend()

# %%
#regrouper ces titres en titres plus utiles

Title_Dictionary = {"Capt":       "Officer",
                    "Col":        "Officer",
                    "Major":      "Officer",
                      "Dr":         "Officer",
                    "Rev":        "Officer",
                    "Jonkheer":   "Royalty",
                    "Don":        "Royalty",
                    "Sir" :       "Royalty",

                   "Lady" :      "Royalty",

                  "the Countess": "Royalty",

                    "Dona":       "Royalty",

                    "Mme":        "Miss",

                    "Mlle":       "Miss",

                    "Miss" :      "Miss",

                    "Ms":         "Mrs",

                    "Mr" :        "Mrs",

                    "Mrs" :       "Mrs",

                    "Master" :    "Master",

                    }
Titre=new_data["Titre"]
Titre.keys()
Titre=dict(Titre)
Titre
if  Title_Dictionary.keys() in Titre.values():
    for value in Titre.items():
        Titre[value].update(Title_Dictionary[value])
Titre
# Out:
# {0: 'Collander  Mr. Erik Gustaf',
#  1: 'Moen  Mr. Sigurd Hansen',
#  2: 'Jensen  Mr. Hans Peder',
#  3: 'Palsson  Mrs. Nils (Alma Cornelia Berglund)',
#  4: 'Davidson  Mr. Thornton',
#  5: 'Gustafsson  Mr. Anders Vilhelm',
#  6: 'Patchett  Mr. George',
#  7: 'Nakid  Miss. Maria ("Mary")',
#  8: 'Lovell  Mr. John Hall ("Henry")',
#  9: 'Louch  Mrs. Charles Alexander (Alice Adelaide Slow)',
#  10: 'Sobey  Mr. Samuel James Hayden',
#  11: 'Haas  Miss. Aloisia',
#  12: 'Herman  Mrs. Samuel (Jane Laver)',
#  13: 'Chapman  Mr. John Henry',
#  14: 'McMahon  Mr. Martin',
#  15: 'Kallio  Mr. Nikolai Erland',
#  16: 'Widener  Mr. Harry Elkins',
#  17: 'Elias  Mr. Joseph Jr',
#  18: 'Hickman  Mr. Lewis',
#  19: 'Hoyt  Mr. Frederick Maxfield',
#  20: 'McDermott  Miss. Brigdet Delia',
#  21: 'Ekstrom  Mr. Johan',
#  22: 'Beane  Mr. Edward',
#  23: 'Tomlin  Mr. Ernest Portage',
#  24: 'Mellinger  Mrs. (Elizabeth Anne Maidment)',
#  25: 'Milling  Mr. Jacob Christian',
# ...

# %%
# creation de FamilySize Parch et SibSp pour créer une fonctionnalité plus utile, appelons-la 
new_data["FamilySize"]= new_data["Parch"]+ new_data["SibSp"]
new_data
# Out:
#      PassengerId Survived  Pclass     Sex  Age  SibSp  Parch      Ticket  \
# 0            343       No       2    male   28      0      0      248740
# 1             76       No       3    male   25      0      0      348123
# 2            641       No       3    male   20      0      0      350050
# 3            568       No       3  female   29      0      4      349909
# 4            672       No       1    male   31      1      0  F.C. 12750
# ..           ...      ...     ...     ...  ...    ...    ...         ...
# 886           10      Yes       2  female   14      1      0      237736
# 887           61       No       3    male   22      0      0        2669
# 888          535       No       3  female   30      0      0      315084
# 889          102       No       3    male   29      0      0      349215
# 890          428      Yes       2  female   19      0      0      250655
#
#         Fare Cabin Embarked  \
# 0    13.0000     3        S
# 1     7.6500    15        S
# ...
